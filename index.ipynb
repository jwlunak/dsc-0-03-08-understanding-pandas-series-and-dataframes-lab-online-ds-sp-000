# %% [markdown]
# # Understanding Pandas Series and DataFrames - Lab

# %% [markdown]
# # Introduction
#
# In this lab, let's get some hands on practice working with data cleanup using Pandas.

# %% [markdown]
# ## Objectives
# You will be able to:
#
# * Manipulate columns in DataFrames (df.rename, df.drop)
# * Manipulate the index in DataFrames (df.reindex, df.drop, df.rename)
# * Manipulate column datatypes

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('turnstile_180901.txt')
print(len(df))
df.head()
# Out:
# 197625
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    EXITS
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# # Practice
#
# ## Objectives
# You will be able to:
# * Understand and explain what Pandas Series and DataFrames are and how they differ from dictionaries and lists
# * Create Series & DataFrames from dictionaries and lists
# * Manipulate columns in DataFrames (df.rename, df.drop)
# * Manipulate the index in DataFrames (df.reindex, df.drop, df.rename)
# * Manipulate column datatypes

# %% [markdown]
# # Rename all the columns to lower case

# %%
#Your code here
df = df.rename(columns={'C/A': 'c/a', 'UNIT': 'unit', 'SCP':'scp', 'STATION': 'station', 'LINENAME': 'linename', 'DIVISION':'division', 'DATE':
                  'date', 'TIME':'time', 'DESC':'desc', 'ENTRIES':'entries', 'EXITS                                                               ':'exits'})
df.head(2)
# Out:
#            c/a  unit       scp station division        date      time  \
# linename
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  00:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  04:00:00
#
#              desc  entries    exits
# linename
# NQR456W   REGULAR  6736067  2283184
# NQR456W   REGULAR  6736087  2283188

# %% [markdown]
# # Change the Index to be the Line Names

# %%
df = df.set_index('linename')
df.head()
# Out:
#            c/a  unit       scp station division        date      time  \
# linename
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  00:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  04:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  08:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  12:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  16:00:00
#
#              desc  entries    exits
# linename
# NQR456W   REGULAR  6736067  2283184
# NQR456W   REGULAR  6736087  2283188
# NQR456W   REGULAR  6736105  2283229
# NQR456W   REGULAR  6736180  2283314
# NQR456W   REGULAR  6736349  2283384

# %% [markdown]
# # Painstakingly change the index back

# %%
df = df.reset_index()
df.head()
# Out:
#    index linename   c/a  unit       scp station division        date  \
# 0      0  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018
# 1      1  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018
# 2      2  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018
# 3      3  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018
# 4      4  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018
#
#        time     desc  entries    exits
# 0  00:00:00  REGULAR  6736067  2283184
# 1  04:00:00  REGULAR  6736087  2283188
# 2  08:00:00  REGULAR  6736105  2283229
# 3  12:00:00  REGULAR  6736180  2283314
# 4  16:00:00  REGULAR  6736349  2283384

# %% [markdown]
# ## Create another column 'Num_Lines' that is a count of how many lines pass through a station. Then sort your dataframe by this column in descending order.

# %%
df['Num_Lines'] = df.linename.map(lambda x: len(x))
df.head(10)
# Out:
#    index linename   c/a  unit       scp station division        date  \
# 0      0  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018
# 1      1  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018
# 2      2  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018
# 3      3  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018
# 4      4  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018
# 5      5  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018
# 6      6  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/26/2018
# 7      7  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/26/2018
# 8      8  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/26/2018
# 9      9  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/26/2018
#
#        time     desc  entries    exits  Num_Lines
# 0  00:00:00  REGULAR  6736067  2283184          7
# 1  04:00:00  REGULAR  6736087  2283188          7
# 2  08:00:00  REGULAR  6736105  2283229          7
# ...

# %%
df.set_index('Num_Lines')
# Out:
#             index linename    c/a  unit       scp        station division  \
# Num_Lines
# 7               0  NQR456W   A002  R051  02-00-00          59 ST      BMT
# 7               1  NQR456W   A002  R051  02-00-00          59 ST      BMT
# 7               2  NQR456W   A002  R051  02-00-00          59 ST      BMT
# 7               3  NQR456W   A002  R051  02-00-00          59 ST      BMT
# 7               4  NQR456W   A002  R051  02-00-00          59 ST      BMT
# 7               5  NQR456W   A002  R051  02-00-00          59 ST      BMT
# 7               6  NQR456W   A002  R051  02-00-00          59 ST      BMT
# 7               7  NQR456W   A002  R051  02-00-00          59 ST      BMT
# 7               8  NQR456W   A002  R051  02-00-00          59 ST      BMT
# 7               9  NQR456W   A002  R051  02-00-00          59 ST      BMT
# 7              10  NQR456W   A002  R051  02-00-00          59 ST      BMT
# ...

# %% [markdown]
# ## Write a function to clean a column name.

# %%
def clean(col_name):
    cleaned = col_name.capitalize() #Your code here; whatever you want to do to col_name. Hint: think back to str methods.
    return cleaned

# %%
#This is a list comprehension. It applies your clean function to every item in the list.
#We then reassign that to df.columns
#You shouldn't have to change anything here.
#Your function above should work appropriately here.
df.columns = [clean(col) for col in df.columns]

# %%
#Checking the output, we can see the results.
df.columns
# Out:
# Index(['Index', 'Linename', 'C/a', 'Unit', 'Scp', 'Station', 'Division',
#        'Date', 'Time', 'Desc', 'Entries', 'Exits', 'Num_lines'],
#       dtype='object')

# %% [markdown]
# ## Compare subway traffic by day of the week. Display this as a graph.

# %%
#Your code here
df.Date = pd.to_datetime(df.Date, format = '%a')

# %%
df['DayoftheWeek'] = df.Date.dt.day_name()
df.head(2)
# Out:
#    Index Linename   C/a  Unit       Scp Station Division       Date      Time  \
# 0      0  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  00:00:00
# 1      1  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  04:00:00
#
#       Desc  Entries    Exits  Num_lines DayoftheWeek
# 0  REGULAR  6736067  2283184          7     Saturday
# 1  REGULAR  6736087  2283188          7     Saturday

# %%
grouped = df.groupby('DayoftheWeek').sum()
grouped.plot(kind='barh')

# %% [markdown]
# ## Is there more subway traffic on a weekend or a weekday?    Be specific in comparing magnitudes.

# %%
#Your code here
grouped.head()
# Out:
#                    Index        Entries         Exits  Num_lines
# DayoftheWeek
# Friday        2778112001  1110224700078  906799065337      75573
# Monday        2783610827  1114237052454  911938153513      76110
# Saturday      2741377942  1115661545514  909142081474      74725
# Sunday        2792287000  1192306179082  959223750461      75306
# Thursday      2817391725  1122723988662  920691927110      76607

# %%
grouped = grouped.reset_index()

# %%
grouped['Weekend'] = grouped.DayoftheWeek.map({'Friday':False, 'Monday':False, 'Saturday':True, 'Sunday': True, 'Thursday':False, 'Tuesday': False, 'Wednesday': False})
grouped.head()
# Out:
#   DayoftheWeek       Index        Entries         Exits  Num_lines  Weekend
# 0       Friday  2778112001  1110224700078  906799065337      75573    False
# 1       Monday  2783610827  1114237052454  911938153513      76110    False
# 2     Saturday  2741377942  1115661545514  909142081474      74725     True
# 3       Sunday  2792287000  1192306179082  959223750461      75306     True
# 4     Thursday  2817391725  1122723988662  920691927110      76607    False

# %%
num_weekend = grouped.groupby('Weekend').mean()
num_weekend[['Entries','Exits']].plot(kind='barh')

# %%
num_weekend.head()
# Out:
#                 Index       Entries         Exits  Num_lines
# Weekend
# False    2.798811e+09  1.122831e+12  9.204581e+11    76261.2
# True     2.766832e+09  1.153984e+12  9.341829e+11    75015.5

# %% [markdown]
# # Drop a couple of columns

# %%
# Your code here
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197625 entries, 0 to 197624
# Data columns (total 14 columns):
# Index           197625 non-null int64
# Linename        197625 non-null object
# C/a             197625 non-null object
# Unit            197625 non-null object
# Scp             197625 non-null object
# Station         197625 non-null object
# Division        197625 non-null object
# Date            197625 non-null datetime64[ns]
# Time            197625 non-null object
# Desc            197625 non-null object
# Entries         197625 non-null int64
# Exits           197625 non-null int64
# Num_lines       197625 non-null int64
# DayoftheWeek    197625 non-null object
# dtypes: datetime64[ns](1), int64(4), object(9)
# memory usage: 21.1+ MB

# %%
df=df.drop('Division', axis=1)

# %%
df.head(2)
# Out:
#    Index Linename   C/a  Unit       Scp Station       Date      Time     Desc  \
# 0      0  NQR456W  A002  R051  02-00-00   59 ST 2018-08-25  00:00:00  REGULAR
# 1      1  NQR456W  A002  R051  02-00-00   59 ST 2018-08-25  04:00:00  REGULAR
#
#    Entries    Exits  Num_lines DayoftheWeek
# 0  6736067  2283184          7     Saturday
# 1  6736087  2283188          7     Saturday

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197625 entries, 0 to 197624
# Data columns (total 13 columns):
# Index           197625 non-null int64
# Linename        197625 non-null object
# C/a             197625 non-null object
# Unit            197625 non-null object
# Scp             197625 non-null object
# Station         197625 non-null object
# Date            197625 non-null datetime64[ns]
# Time            197625 non-null object
# Desc            197625 non-null object
# Entries         197625 non-null int64
# Exits           197625 non-null int64
# Num_lines       197625 non-null int64
# DayoftheWeek    197625 non-null object
# dtypes: datetime64[ns](1), int64(4), object(8)
# memory usage: 19.6+ MB

# %%
df=df.drop('Unit', axis=1)

# %%
df.head(2)
# Out:
#    Index Linename   C/a       Scp Station       Date      Time     Desc  \
# 0      0  NQR456W  A002  02-00-00   59 ST 2018-08-25  00:00:00  REGULAR
# 1      1  NQR456W  A002  02-00-00   59 ST 2018-08-25  04:00:00  REGULAR
#
#    Entries    Exits  Num_lines DayoftheWeek
# 0  6736067  2283184          7     Saturday
# 1  6736087  2283188          7     Saturday
